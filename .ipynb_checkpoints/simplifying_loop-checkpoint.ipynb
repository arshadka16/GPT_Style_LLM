# %%
all_words = [" apple ", " banana", " ", "orange ", "","strawbery"]
new_words =[]
for word in all_words:
    real_word = word.strip()
    if real_word:
        new_words.append(real_word)

# %%
new = [word.strip() for word in all_words if word.strip()]

# %%
new_words
# Out:
# ['apple', 'banana', 'orange', 'strawbery']

# %%
vocab = {"apple": 1, "banana": 2}
words = ["apple", "grape", "banana"]
result = []
for item in words:
    if item in vocab:
        result.append(item)
    else:
        result.append("|<unk>|")

# %%
process = [item if item in vocab else "|<unk>|" for item in words]

# %%
process
# Out:
# ['apple', '|<unk>|', 'banana']
